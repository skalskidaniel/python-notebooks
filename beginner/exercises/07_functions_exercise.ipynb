# %% [markdown]
# # 1. Uzupełnij brakujące elementy funkcji `count_even_numbers`
# Uzupełnij `____` w implementacji `count_even_numbers`, aby przejść asercje. Możesz założyć, że argument `numbers` jest listą liczb całkowitych.

# %%
____ count_even_numbers(numbers):
    count = 0
    for num in ____:
        if ____ % 2 == ____:
            count += ____
    _____ _____

# %%
assert count_even_numbers([1, 2, 3, 4, 5, 6]) == 3
assert count_even_numbers([1, 3, 5, 7]) == 0
assert count_even_numbers([-2, 2, -10, 8]) == 4

# %% [markdown]
# # 2. Wyszukiwanie poszukiwanych osób
# Zaimplementuj funkcję `find_wanted_people`, która jako argument przyjmuje listę imion (ciągów znaków). Funkcja powinna zwrócić listę imion, które znajdują się zarówno w `WANTED_PEOPLE`, jak i na liście imion podanej jako argument funkcji.

# %%
WANTED_PEOPLE = ["John Doe", "Clint Eastwood", "Chuck Norris"]

# %%
# Twoja implementacja tutaj

# %%
people_to_check1 = ["Donald Duck", "Clint Eastwood", "John Doe", "Barack Obama"]
wanted1 = find_wanted_people(people_to_check1)
assert len(wanted1) == 2
assert "John Doe" in wanted1
assert "Clint Eastwood" in wanted1

people_to_check2 = ["Donald Duck", "Mickey Mouse", "Zorro", "Superman", "Robin Hood"]
wanted2 = find_wanted_people(people_to_check2)
assert wanted2 == []

# %% [markdown]
# # 3. Obliczanie średniej długości słów w zdaniu
# Utwórz funkcję `average_length_of_words`, która przyjmuje jako argument ciąg znaków i zwraca średnią długość słów w ciągu. Możesz założyć, że między każdym słowem jest pojedyncza spacja, a dane wejściowe nie zawierają znaków interpunkcyjnych. Wynik powinien być zaokrąglony do jednego miejsca po przecinku (wskazówka: zobacz [`round`](https://docs.python.org/3/library/functions.html#round)).

# %%
# Twoja implementacja tutaj

# %%
assert average_length_of_words("only four lett erwo rdss") == 4
assert average_length_of_words("one two three") == 3.7
assert average_length_of_words("one two three four") == 3.8
assert average_length_of_words("") == 0
