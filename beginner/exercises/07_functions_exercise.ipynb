# %% [markdown]
# # 1. Uzupełnij brakujące elementy funkcji `policz_liczby_parzyste`
# Uzupełnij `____` w implementacji `policz_liczby_parzyste`, aby przejść asercje. Możesz założyć, że argument `liczby` jest listą liczb całkowitych.

# %%
____ policz_liczby_parzyste(liczby):
    licznik = 0
    for liczba in ____:
        if ____ % 2 == ____:
            licznik += ____
    _____ _____

# %%
assert policz_liczby_parzyste([1, 2, 3, 4, 5, 6]) == 3
assert policz_liczby_parzyste([1, 3, 5, 7]) == 0
assert policz_liczby_parzyste([-2, 2, -10, 8]) == 4

# %% [markdown]
# # 2. Wyszukiwanie poszukiwanych osób
# Zaimplementuj funkcję `znajdz_poszukiwane_osoby`, która jako argument przyjmuje listę imion (ciągów znaków). Funkcja powinna zwrócić listę imion, które znajdują się zarówno w `POSZUKIWANE_OSOBY`, jak i na liście imion podanej jako argument funkcji.

# %%
POSZUKIWANE_OSOBY = ["Jan Kowalski", "Clint Eastwood", "Chuck Norris"]

# %%
# Twoja implementacja tutaj

# %%
osoby_do_sprawdzenia1 = ["Kaczor Donald", "Clint Eastwood", "Jan Kowalski", "Barack Obama"]
poszukiwane1 = znajdz_poszukiwane_osoby(osoby_do_sprawdzenia1)
assert len(poszukiwane1) == 2
assert "Jan Kowalski" in poszukiwane1
assert "Clint Eastwood" in poszukiwane1

osoby_do_sprawdzenia2 = ["Kaczor Donald", "Myszka Miki", "Zorro", "Superman", "Robin Hood"]
poszukiwane2 = znajdz_poszukiwane_osoby(osoby_do_sprawdzenia2)
assert poszukiwane2 == []

# %% [markdown]
# # 3. Obliczanie średniej długości słów w zdaniu
# Utwórz funkcję `srednia_dlugosc_slow`, która przyjmuje jako argument ciąg znaków i zwraca średnią długość słów w ciągu. Możesz założyć, że między każdym słowem jest pojedyncza spacja, a dane wejściowe nie zawierają znaków interpunkcyjnych. Wynik powinien być zaokrąglony do jednego miejsca po przecinku (wskazówka: zobacz [`round`](https://docs.python.org/3/library/functions.html#round)).

# %%
# Twoja implementacja tutaj

# %%
assert srednia_dlugosc_slow("tylko czter y lit ter y slow a") == 4
assert srednia_dlugosc_slow("jeden dwa trzy") == 3.7
assert srednia_dlugosc_slow("jeden dwa trzy cztery") == 3.8
assert srednia_dlugosc_slow("") == 0
