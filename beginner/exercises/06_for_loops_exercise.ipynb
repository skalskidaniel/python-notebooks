# %% [markdown]
# # 1. Uzupełnij brakujące elementy
# Uzupełnij `____` w poniższym kodzie.

# %%
words = ["PYTHON", "JOHN", "chEEse", "hAm", "DOE", "123"]
upper_case_words = []

for ____ in words:
    if ____.isupper():
        ____.append(____)

# %%
assert upper_case_words == ["PYTHON", "JOHN", "DOE"]

# %% [markdown]
# # 2. Oblicz sumę wartości słownika
# Oblicz sumę wartości w `magic_dict`, biorąc pod uwagę tylko wartości numeryczne (wskazówka: zobacz [isinstance](https://docs.python.org/3/library/functions.html#isinstance)).

# %%
magic_dict = dict(val1=44, val2="secret value", val3=55.0, val4=1)

# %%
# Twoja implementacja
sum_of_values =

# %%
assert sum_of_values == 100

# %% [markdown]
# # 3. Utwórz listę ciągów znaków na podstawie listy liczb
# Zasady:
# * Jeśli liczba jest wielokrotnością pięciu i jest nieparzysta, ciąg znaków powinien brzmieć `'five odd'`
# * Jeśli liczba jest wielokrotnością pięciu i jest parzysta, ciąg znaków powinien brzmieć `'five even'`
# * Jeśli liczba jest nieparzysta, ciąg znaków to `'odd'`
# * Jeśli liczba jest parzysta, ciąg znaków to `'even'`

# %%
numbers = [1, 3, 4, 6, 81, 80, 100, 95]

# %%
# Twoja implementacja
my_list =

# %%
assert my_list == [
    "odd",
    "odd",
    "even",
    "even",
    "odd",
    "five even",
    "five even",
    "five odd",
]
