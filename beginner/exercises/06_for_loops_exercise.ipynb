# %% [markdown]
# # 1. Uzupełnij brakujące elementy
# Uzupełnij `____` w poniższym kodzie.

# %%
slowa = ["PYTHON", "JAN", "sEr", "sZynKa", "KOWALSKI", "123"]
slowa_wielkimi_literami = []

for ____ in slowa:
    if ____.isupper():
        ____.append(____)

# %%
assert slowa_wielkimi_literami == ["PYTHON", "JAN", "KOWALSKI"]

# %% [markdown]
# # 2. Oblicz sumę wartości słownika
# Oblicz sumę wartości w `magiczny_slownik`, biorąc pod uwagę tylko wartości numeryczne (wskazówka: zobacz [isinstance](https://docs.python.org/3/library/functions.html#isinstance)).

# %%
magiczny_slownik = dict(wartosc1=44, wartosc2="sekretna wartość", wartosc3=55.0, wartosc4=1)

# %%
# Twoja implementacja
suma_wartosci =

# %%
assert suma_wartosci == 100

# %% [markdown]
# # 3. Utwórz listę ciągów znaków na podstawie listy liczb
# Zasady:
# * Jeśli liczba jest wielokrotnością pięciu i jest nieparzysta, ciąg znaków powinien brzmieć `'piec nieparzysta'`
# * Jeśli liczba jest wielokrotnością pięciu i jest parzysta, ciąg znaków powinien brzmieć `'piec parzysta'`
# * Jeśli liczba jest nieparzysta, ciąg znaków to `'nieparzysta'`
# * Jeśli liczba jest parzysta, ciąg znaków to `'parzysta'`

# %%
liczby = [1, 3, 4, 6, 81, 80, 100, 95]

# %%
# Twoja implementacja
moja_lista =

# %%
assert moja_lista == [
    "nieparzysta",
    "nieparzysta",
    "parzysta",
    "parzysta",
    "nieparzysta",
    "piec parzysta",
    "piec parzysta",
    "piec nieparzysta",
]
