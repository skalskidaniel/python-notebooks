# %% [markdown]
# # 1. Radzenie sobie z wyjątkami
# Uzupełnij `____` w poniższej implementacji. Funkcja `sum_of_list` przyjmuje listę jako argument i oblicza sumę wartości na liście. Jeśli jakiegoś elementu na liście nie można przekonwertować na wartość numeryczną, należy go zignorować w sumie.

# %%
def sum_of_list(values):
    ____ = 0
    for val in values:
        ____:
            numeric_val = float(val)
        ____ ____ as e:
            ____
        ____ += numeric_val
    return ____

# %%
list1 = [1, 2, 3]
list2 = ["1", 2.5, "3.0"]
list3 = ["", "1"]
list4 = []
list5 = ["John", "Doe", "was", "here"]
nasty_list = [KeyError(), [], dict()]

assert sum_of_list(list1) == 6
assert sum_of_list(list2) == 6.5
assert sum_of_list(list3) == 1
assert sum_of_list(list4) == 0
assert sum_of_list(list5) == 0
assert sum_of_list(nasty_list) == 0

# %% [markdown]
# # 2. Używanie niestandardowych wyjątków
# Zaimplementuj funkcję `verify_short_string`, która przyjmuje jako argument pojedynczy ciąg znaków. Jeśli długość ciągu wejściowego jest większa niż dziesięć znaków, funkcja powinna zgłosić wyjątek `TooLongString` (uwaga: musisz samodzielnie utworzyć `TooLongString`). Funkcja nie musi niczego zwracać.

# %%
# Twoja implementacja tutaj

# %%
# Te nie powinny zgłaszać błędu
verify_short_string("short")
verify_short_string("10   chars")

# To powinno zgłosić błąd
try:
    verify_short_string("this is long")
except TooLongString as e:
    # To jest w porządku
    pass
else:
    # Oznacza to, że nie było wyjątku
    assert False
