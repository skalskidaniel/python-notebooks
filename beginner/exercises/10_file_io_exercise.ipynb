# %%
# WYKONAJ TĘ KOMÓRKĘ JAKO PIERWSZĄ!

from pathlib import Path

# Stałe do ćwiczeń:
WORKING_DIR = Path.cwd()
DATA_DIR = WORKING_DIR.parent / "data"

# %% [markdown]
# # 1. Zsumuj liczby wymienione w pliku
# Uzupełnij `____` w poniższym kodzie. Funkcja `sum_numbers_in_file` przyjmuje jako argument ścieżkę do pliku wejściowego, odczytuje liczby wymienione w pliku wejściowym i zwraca sumę tych liczb. Możesz założyć, że każda linia zawiera dokładnie jedną wartość numeryczną.

# %%
def sum_numbers_in_file(input_file):
    total = 0
    with ____(input_file) as ____:
        for line in ____:
            ____ = line.strip()  # Remove potential white space
            total += float(____)
    return _____

# %%
in_file = DATA_DIR / "numbers.txt"
assert sum_numbers_in_file(in_file) == 189.5

# %% [markdown]
# # 2. Odczytywanie pierwszego słowa z każdej linii pliku
# Zaimplementuj funkcję `find_first_words`, która przyjmuje jako argument ścieżkę do pliku wejściowego. Funkcja powinna znaleźć pierwsze słowo w każdej linii pliku i zwrócić te słowa jako listę. Jeśli linia jest pusta, zwracana lista powinna zawierać pusty ciąg znaków dla tej linii.

# %%
# Twoja implementacja tutaj

# %%
in_file1 = DATA_DIR / "simple_file.txt"
in_file2 = DATA_DIR / "simple_file_with_empty_lines.txt"

expected_file_1 = ["First", "Second", "Third", "And"]
assert find_first_words(in_file1) == expected_file_1

expected_file_2 = ["The", "", "First", "nonsense", "", "Then"]
assert find_first_words(in_file2) == expected_file_2
