# %%
# WYKONAJ TĘ KOMÓRKĘ JAKO PIERWSZĄ!

from pathlib import Path

# Stałe do ćwiczeń:
KATALOG_ROBOCZY = Path.cwd()
KATALOG_DANYCH = KATALOG_ROBOCZY.parent / "data"

# %% [markdown]
# # 1. Zsumuj liczby wymienione w pliku
# Uzupełnij `____` w poniższym kodzie. Funkcja `zsumuj_liczby_w_pliku` przyjmuje jako argument ścieżkę do pliku wejściowego, odczytuje liczby wymienione w pliku wejściowym i zwraca sumę tych liczb. Możesz założyć, że każda linia zawiera dokładnie jedną wartość numeryczną.

# %%
def zsumuj_liczby_w_pliku(plik_wejsciowy):
    suma = 0
    with ____(plik_wejsciowy) as ____:
        for linia in ____:
            ____ = linia.strip()  # Usuń potencjalne białe znaki
            suma += float(____)
    return _____

# %%
plik_wej = KATALOG_DANYCH / "numbers.txt"
assert zsumuj_liczby_w_pliku(plik_wej) == 189.5

# %% [markdown]
# # 2. Odczytywanie pierwszego słowa z każdej linii pliku
# Zaimplementuj funkcję `znajdz_pierwsze_slowa`, która przyjmuje jako argument ścieżkę do pliku wejściowego. Funkcja powinna znaleźć pierwsze słowo w każdej linii pliku i zwrócić te słowa jako listę. Jeśli linia jest pusta, zwracana lista powinna zawierać pusty ciąg znaków dla tej linii.

# %%
# Twoja implementacja tutaj

# %%
plik_wej1 = KATALOG_DANYCH / "simple_file.txt"
plik_wej2 = KATALOG_DANYCH / "simple_file_with_empty_lines.txt"

oczekiwany_plik_1 = ["First", "Second", "Third", "And"]
assert znajdz_pierwsze_slowa(plik_wej1) == oczekiwany_plik_1

oczekiwany_plik_2 = ["The", "", "First", "nonsense", "", "Then"]
assert znajdz_pierwsze_slowa(plik_wej2) == oczekiwany_plik_2
