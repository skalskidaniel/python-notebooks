# %% [markdown]
# # 1. Super samogłoski
# Zaimplementuj funkcję `super_vowels`, która przyjmuje jako argument ciąg znaków i zwraca zmodyfikowaną wersję tego ciągu. W wartości zwracanej przez `super_vowels` wszystkie samogłoski powinny być pisane wielkimi literami, podczas gdy wszystkie spółgłoski powinny być pisane małymi literami. Samogłoski są wymienione w zmiennej `VOWELS`.

# %%
VOWELS = ["a", "e", "i", "o", "u"]

# %%
# Twoja implementacja tutaj

# %%
assert super_vowels("hi wassup!") == "hI wAssUp!"
assert super_vowels("HOw aRE You?") == "hOw ArE yOU?"

# %% [markdown]
# # 2. Plansza do gry
# Zaimplementuj funkcję `get_playing_board`, która przyjmuje jako argument liczbę całkowitą. Funkcja powinna zwracać ciąg znaków przypominający planszę do gry (np. szachownicę). Plansza powinna zawierać tyle wierszy i kolumn, ile podano w argumencie całkowitoliczbowym. Zobacz komórkę poniżej, aby zapoznać się z przykładami pożądanego zachowania.

# %%
# Twoja implementacja tutaj

# %%
board_of_5 = " * * \n" "* * *\n" " * * \n" "* * *\n" " * * \n"

board_of_10 = (
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
)

assert get_playing_board(5) == board_of_5
assert get_playing_board(10) == board_of_10

print(get_playing_board(50))
