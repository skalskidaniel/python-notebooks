# %% [markdown]
# # 1. Uzupełnij brakujące elementy
# Uzupełnij `____`, aby uzyskać poprawne wartości dla zmiennych `male_litery`, `przyciety` i `przyciety_male_litery`.

# %%
oryginalny = " Stringi Pythona sa SUPER! "
male_litery = oryginalny._____
przyciety = ____.strip()
przyciety_male_litery = oryginalny._____._____

# %% [markdown]
# Sprawdźmy, czy implementacja jest poprawna, uruchamiając poniższą komórkę. `assert` zgłosi `AssertionError`, jeśli instrukcja nie jest prawdziwa.

# %%
assert male_litery == " stringi pythona sa super! "
assert przyciety == "Stringi Pythona sa SUPER!"
assert przyciety_male_litery == "stringi pythona sa super!"

# %% [markdown]
# # 2. Upiększ brzydki ciąg znaków
# Użyj metod `str`, aby przekonwertować `brzydki` na `ladny`.

# %%
brzydki = " tytUL mojEJ nowej Ksiazki\n\n"

# %%
# Twoja implementacja:
ladny = "TODO"

# %% [markdown]
# Upewnijmy się, że robi to, co chcemy. `assert` zgłasza [`AssertionError`](https://docs.python.org/3/library/exceptions.html#AssertionError), jeśli instrukcja nie jest `True`.

# %%
print(f"ladny: {ladny}")
assert ladny == "Tytul Mojej Nowej Ksiazki"

# %% [markdown]
# # 3. Sformatuj ciąg znaków na podstawie istniejących zmiennych
# Utwórz `zdanie`, używając `czasownik`, `jezyk` i `interpunkcja` oraz wszelkich innych ciągów znaków, których możesz potrzebować.

# %%
czasownik = "jest"
jezyk = "Python"
interpunkcja = "!"

# %%
# Twoja implementacja:
zdanie = "TODO"

# %%
print(f"zdanie: {zdanie}")
assert zdanie == "Nauka Pythona jest fajna!"
