# %% [markdown]
# # 1. Uzupełnij brakujące elementy
# Uzupełnij `____`, aby uzyskać poprawne wartości dla zmiennych `lower_cased`, `stripped` i `stripped_lower_case`.

# %%
original = " Python strings are COOL! "
lower_cased = original._____
stripped = ____.strip()
stripped_lower_cased = original._____._____

# %% [markdown]
# Sprawdźmy, czy implementacja jest poprawna, uruchamiając poniższą komórkę. `assert` zgłosi `AssertionError`, jeśli instrukcja nie jest prawdziwa.

# %%
assert lower_cased == " python strings are cool! "
assert stripped == "Python strings are COOL!"
assert stripped_lower_cased == "python strings are cool!"

# %% [markdown]
# # 2. Upiększ brzydki ciąg znaków
# Użyj metod `str`, aby przekonwertować `ugly` na `pretty`.

# %%
ugly = " tiTle of MY new Book\n\n"

# %%
# Twoja implementacja:
pretty = "TODO"

# %% [markdown]
# Upewnijmy się, że robi to, co chcemy. `assert` zgłasza [`AssertionError`](https://docs.python.org/3/library/exceptions.html#AssertionError), jeśli instrukcja nie jest `True`.

# %%
print(f"pretty: {pretty}")
assert pretty == "Title Of My New Book"

# %% [markdown]
# # 3. Sformatuj ciąg znaków na podstawie istniejących zmiennych
# Utwórz `sentence`, używając `verb`, `language` i `punctuation` oraz wszelkich innych ciągów znaków, których możesz potrzebować.

# %%
verb = "is"
language = "Python"
punctuation = "!"

# %%
# Twoja implementacja:
sentence = "TODO"

# %%
print(f"sentence: {sentence}")
assert sentence == "Learning Python is fun!"
