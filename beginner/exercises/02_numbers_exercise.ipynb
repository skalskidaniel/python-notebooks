# %% [markdown]
# # 1. Tworzenie formuł
# Napisz następującą formułę matematyczną w Pythonie:
#
# \begin{align}
#  result = 6a^3 - \frac{8b^2 }{4c} + 11
# \end{align}

# %%
a = 2
b = 3
c = 2

# %%
# Twoja formuła tutaj:
result =

# %%
assert result == 50

# %% [markdown]
# # 2. Pułapki liczb zmiennoprzecinkowych
# Pokaż, że `0.1 + 0.2 == 0.3`

# %%
# Twoje rozwiązanie tutaj

# To nie zadziała:
# assert 0.1 + 0.2 == 0.3
