# %% [markdown]
# # 1. Zabawa z datami i czasem
# Masz podaną naiwną datę i czas, zobacz zmienną `NAIWNA_DT` poniżej. Chociaż ta zmienna jest naiwna, wiesz, że czas określony przez `NAIWNA_DT` jest w UTC.
#
# Na podstawie tych informacji Twoim zadaniem jest utworzenie nowych zmiennych daty i czasu poprzez konwersję `NAIWNA_DT` na UTC, a następnie na czas w Sydney i Los Angeles. Użyj następujących nazw zmiennych: `utc_dt`, `sydney_dt` i `la_dt`.

# %%
import datetime as dt
from zoneinfo import ZoneInfo, available_timezones

NAIWNA_DT = dt.datetime(2000, 1, 1, 10)

# %% [markdown]
# Jeśli nie znasz nazwy strefy czasowej, której szukasz, to może być pomocne:

# %%
for strefa in available_timezones():
    print(strefa)

# %% [markdown]
# Teraz utwórz `utc_dt`, `sydney_dt` i `la_dt`.

# %%
# Twoja implementacja tutaj

# %% [markdown]
# Sprawdźmy, czy rozwiązanie jest poprawne.

# %%
assert utc_dt.isoformat() == "2000-01-01T10:00:00+00:00"
assert sydney_dt.isoformat() == "2000-01-01T21:00:00+11:00"
assert la_dt.isoformat() == "2000-01-01T02:00:00-08:00"

print("Wszystko działa!")
