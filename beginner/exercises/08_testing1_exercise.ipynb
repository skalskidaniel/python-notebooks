# %%
# Upewnijmy się, że pakiety pytest i ipytest są zainstalowane
# ipytest jest wymagany do uruchamiania pytest wewnątrz notatników Jupyter
import sys

# !{sys.executable} -m pip install pytest
# !{sys.executable} -m pip install ipytest

# Są one potrzebne do uruchamiania pytest wewnątrz notatników Jupyter
import ipytest

ipytest.autoconfig()

# %% [markdown]
# # 1. Tworzenie pierwszego przypadku testowego
# W komórce poniżej znajduje się implementacja funkcji `get_divisible_by_five`. Twoim zadaniem jest utworzenie przypadku testowego dla tej funkcji, aby sprawdzić, czy działa poprawnie.

# %%
def get_divisible_by_five(numbers):
    """Returns a list of numbers which are divisible by five in the list got as an argument"""
    result = []
    for num in numbers:
        if not num % 5:
            result.append(num)

    return result

# %%
# %%ipytest
#
# def test_get_divisible_by_five():
#     # Twoja implementacja tutaj
