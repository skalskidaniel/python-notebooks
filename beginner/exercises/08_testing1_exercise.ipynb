# %%
# Upewnijmy się, że pakiety pytest i ipytest są zainstalowane
# ipytest jest wymagany do uruchamiania pytest wewnątrz notatników Jupyter
import sys

# !{sys.executable} -m pip install pytest
# !{sys.executable} -m pip install ipytest

# Są one potrzebne do uruchamiania pytest wewnątrz notatników Jupyter
import ipytest

ipytest.autoconfig()

# %% [markdown]
# # 1. Tworzenie pierwszego przypadku testowego
# W komórce poniżej znajduje się implementacja funkcji `pobierz_podzielne_przez_piec`. Twoim zadaniem jest utworzenie przypadku testowego dla tej funkcji, aby sprawdzić, czy działa poprawnie.

# %%
def pobierz_podzielne_przez_piec(liczby):
    """Zwraca listę liczb, które są podzielne przez pięć z listy otrzymanej jako argument"""
    wynik = []
    for liczba in liczby:
        if not liczba % 5:
            wynik.append(liczba)

    return wynik

# %%
# %%ipytest
#
# def test_pobierz_podzielne_przez_piec():
#     # Twoja implementacja tutaj
