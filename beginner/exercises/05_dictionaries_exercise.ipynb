# %% [markdown]
# # 1. Wypełnianie słownika
# Utwórz słownik, używając wszystkich podanych zmiennych.

# %%
imie = "Jan"
nazwisko = "Kowalski"
ulubione_hobby = "Python"
hobby_sportowe = "silownia"
wiek = 82

# %%
# Twoja implementacja
moj_slownik =

# %%
assert moj_slownik == {"imie": "Jan Kowalski", "wiek": 82, "hobby": ["Python", "silownia"]}

# %% [markdown]
# # 2. Dostęp i łączenie słowników
# Połącz `slownik1`, `slownik2` i `slownik3` w `moj_slownik`. Dodatkowo, pobierz wartość `specjalny_klucz` z `moj_slownik` do zmiennej `specjalna_wartosc`. Pamiętaj, że oryginalne słowniki powinny pozostać nietknięte, a `specjalny_klucz` powinien zostać usunięty z `moj_slownik`.

# %%
slownik1 = dict(klucz1="To nie jest takie trudne", klucz2="Python jest nadal super")
slownik2 = {"klucz1": 123, "specjalny_klucz": "sekret"}
# To jest też sposób na zainicjalizowanie słownika (lista krotek)
slownik3 = dict([("klucz2", 456), ("kluczX", "X")])

# %%
# Twoja implementacja
moj_slownik = 
specjalna_wartosc =

# %%
assert moj_slownik == {"klucz1": 123, "klucz2": 456, "kluczX": "X"}
assert specjalna_wartosc == "sekret"

# Sprawdźmy, czy oryginały są nietknięte
assert slownik1 == {"klucz1": "To nie jest takie trudne", "klucz2": "Python jest nadal super"}
assert slownik2 == {"klucz1": 123, "specjalny_klucz": "sekret"}
assert slownik3 == {"klucz2": 456, "kluczX": "X"}
