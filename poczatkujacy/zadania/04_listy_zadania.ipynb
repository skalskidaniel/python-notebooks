# %% [markdown]
# # 1. Uzupełnij brakujące elementy
# Uzupełnij `____` w poniższym kodzie.

# %%
# Stwórzmy pustą listę
moja_lista = ____

# Dodajmy kilka wartości
moja_lista.____("Python")
moja_lista.____("jest ok")
moja_lista.____("czasami")

# Usuńmy 'czasami'
moja_lista.____("czasami")

# Zmieńmy drugi element
moja_lista[____] = "jest super"

# %%
# Sprawdźmy, czy jest poprawna
assert moja_lista == ["Python", "jest super"]

# %% [markdown]
# # 2. Utwórz nową listę bez modyfikowania oryginalnej

# %%
oryginalna = ["Ja", "uczę", "się", "hakowania", "w"]

# %%
# Twoja implementacja tutaj
zmodyfikowana =

# %%
assert oryginalna == ["Ja", "uczę", "się", "hakowania", "w"]
assert zmodyfikowana == ["Ja", "uczę", "się", "list", "w", "Pythonie"]

# %% [markdown]
# # 3. Utwórz połączoną posortowaną listę

# %%
lista1 = [6, 12, 5]
lista2 = [6.2, 0, 14, 1]
lista3 = [0.9]

# %%
# Twoja implementacja tutaj
moja_lista =

# %%
print(moja_lista)
assert moja_lista == [14, 12, 6.2, 6, 5, 1, 0.9, 0]
