# %% [markdown]
# # 1. Radzenie sobie z wyjątkami
# Uzupełnij `____` w poniższej implementacji. Funkcja `suma_listy` przyjmuje listę jako argument i oblicza sumę wartości na liście. Jeśli jakiegoś elementu na liście nie można przekonwertować na wartość numeryczną, należy go zignorować w sumie.

# %%
def suma_listy(wartosci):
    ____ = 0
    for war in wartosci:
        ____:
            wartosc_numeryczna = float(war)
        ____ ____ as e:
            ____
        ____ += wartosc_numeryczna
    return ____

# %%
lista1 = [1, 2, 3]
lista2 = ["1", 2.5, "3.0"]
lista3 = ["", "1"]
lista4 = []
lista5 = ["Jan", "Kowalski", "byl", "tutaj"]
brzydka_lista = [KeyError(), [], dict()]

assert suma_listy(lista1) == 6
assert suma_listy(lista2) == 6.5
assert suma_listy(lista3) == 1
assert suma_listy(lista4) == 0
assert suma_listy(lista5) == 0
assert suma_listy(brzydka_lista) == 0

# %% [markdown]
# # 2. Używanie niestandardowych wyjątków
# Zaimplementuj funkcję `sprawdz_krotki_ciag`, która przyjmuje jako argument pojedynczy ciąg znaków. Jeśli długość ciągu wejściowego jest większa niż dziesięć znaków, funkcja powinna zgłosić wyjątek `ZbytDlugiCiag` (uwaga: musisz samodzielnie utworzyć `ZbytDlugiCiag`). Funkcja nie musi niczego zwracać.

# %%
# Twoja implementacja tutaj

# %%
# Te nie powinny zgłaszać błędu
sprawdz_krotki_ciag("krotki")
sprawdz_krotki_ciag("10   znakw")

# To powinno zgłosić błąd
try:
    sprawdz_krotki_ciag("to jest dlugie")
except ZbytDlugiCiag as e:
    # To jest w porządku
    pass
else:
    # Oznacza to, że nie było wyjątku
    assert False
