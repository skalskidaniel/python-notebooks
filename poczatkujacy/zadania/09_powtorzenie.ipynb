# %% [markdown]
# # 1. Super samogłoski
# Zaimplementuj funkcję `super_samogloski`, która przyjmuje jako argument ciąg znaków i zwraca zmodyfikowaną wersję tego ciągu. W wartości zwracanej przez `super_samogloski` wszystkie samogłoski powinny być pisane wielkimi literami, podczas gdy wszystkie spółgłoski powinny być pisane małymi literami. Samogłoski są wymienione w zmiennej `SAMOGLOSKI`.

# %%
SAMOGLOSKI = ["a", "e", "i", "o", "u"]

# %%
# Twoja implementacja tutaj

# %%
assert super_samogloski("hi wassup!") == "hI wAssUp!"
assert super_samogloski("HOw aRE You?") == "hOw ArE yOU?"

# %% [markdown]
# # 2. Plansza do gry
# Zaimplementuj funkcję `zwroc_plansze_do_gry`, która przyjmuje jako argument liczbę całkowitą. Funkcja powinna zwracać ciąg znaków przypominający planszę do gry (np. szachownicę). Plansza powinna zawierać tyle wierszy i kolumn, ile podano w argumencie całkowitoliczbowym. Zobacz komórkę poniżej, aby zapoznać się z przykładami pożądanego zachowania.

# %%
# Twoja implementacja tutaj

# %%
plansza_5 = " * * \n" "* * *\n" " * * \n" "* * *\n" " * * \n"

plansza_10 = (
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
    " * * * * *\n"
    "* * * * * \n"
)

assert zwroc_plansze_do_gry(5) == plansza_5
assert zwroc_plansze_do_gry(10) == plansza_10

print(zwroc_plansze_do_gry(50))
